# %%
import pandas as pd
import scipy.stats as s
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
items = pd.read_csv("itemStats.csv")

# Converts the 'N.A.' string to Nan so it can be removed if needed with 
# dropna() and so the column can be converted to a float data type
items = items.replace(['N.A.'], [np.nan])

convertDict = {
    'avgPlatMaxed': float,
    'lastSoldMaxed': float,
    'avgPlatDiff': float,
    'lastSoldPlatDiff': float
}
items = items.astype(convertDict)

# Replaces invalid outliers with NaN
items['avgPlatMaxed'] = items['avgPlatMaxed'].where(items['avgPlatMaxed'] < 177.5, np.nan)
items['avgPlat'] = items['avgPlat'].where(items['avgPlat'] < 125, np.nan)

print(f'The shape of the data is {items.shape} \n')
# Out:
# The shape of the data is (3293, 10)

# %%
display(items.describe())

display(items.info())
# Out:
#         Unnamed: 0      avgPlat     lastSold  avgPlatMaxed  lastSoldMaxed  \
# count  3293.000000  2917.000000  3174.000000    523.000000     562.000000
# mean   1646.000000    16.258622    21.326491     34.005736      41.644995
# std     950.751545    20.100534    55.824668     38.984758      80.280402
# min       0.000000     1.000000     1.000000      5.500000       2.000000
# 25%     823.000000     4.600000     4.717250     12.400000      11.000000
# 50%    1646.000000     9.100000     9.851000     16.300000      17.500000
# 75%    2469.000000    16.600000    20.000000     30.200000      36.541750
# max    3292.000000   122.000000  1800.000000    169.600000    1250.000000
#
#        avgPlatDiff  lastSoldPlatDiff
# count   562.000000        562.000000
# mean     18.073843         22.208434
# std      32.416032         59.600389
# min     -66.000000        -85.000000
# 25%       3.100000          2.292500
# 50%       6.000000          6.000000
# 75%      10.100000         12.490000
# max     300.000000        937.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3293 entries, 0 to 3292
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        3293 non-null   int64
#  1   itemId            3293 non-null   object
#  2   itemName          3293 non-null   object
#  3   itemType          3293 non-null   object
#  4   avgPlat           2917 non-null   float64
#  5   lastSold          3174 non-null   float64
#  6   avgPlatMaxed      523 non-null    float64
#  7   lastSoldMaxed     562 non-null    float64
#  8   avgPlatDiff       562 non-null    float64
#  9   lastSoldPlatDiff  562 non-null    float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 257.4+ KB
# None

# %%
sns.kdeplot(data = items, x = 'avgPlat')
# Out:
# <Axes: xlabel='avgPlat', ylabel='Density'>

# %%
sns.boxplot(data = items, x = 'avgPlat')
# Out:
# <Axes: xlabel='avgPlat'>

# %%
sns.kdeplot(data = items, x = 'avgPlatMaxed')
# Out:
# <Axes: xlabel='avgPlatMaxed', ylabel='Density'>

# %%
sns.boxplot(data = items, x = 'avgPlatMaxed')
# Out:
# <Axes: xlabel='avgPlatMaxed'>

# %%
sns.kdeplot(data = items, x = 'avgPlatDiff')
# Out:
# <Axes: xlabel='avgPlatDiff', ylabel='Density'>

# %%
sns.boxplot(data = items, x = 'avgPlatDiff')
# Out:
# <Axes: xlabel='avgPlatDiff'>
